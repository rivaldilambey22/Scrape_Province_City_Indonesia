# %% [markdown]
# # Web **Scraping**

# %% [markdown]
# Kode ini bertujuan untuk melakukan web scraping pada website https://www.indonesiapostcode.com/location/ untuk mengambil daftar nama provinsi, kota/kabupaten di dalamnya, serta tautan (link) ke halaman detail untuk setiap kota/kabupaten. Hasilnya kemudian disimpan ke dalam file CSV bernama DAFTAR_PROVINSI_KABUPATEN_DAN_LINK.csv.

# %% [markdown]
# Penjelasan langkah demi langkah:
#
# 1. Import Library: Mengimpor library yang dibutuhkan (requests untuk mengambil data dari web, BeautifulSoup untuk mem-parsing HTML, pandas untuk mengelola data dalam DataFrame, dan time untuk memberi jeda).
# 2. Konfigurasi URL dan Selector: Mendefinisikan URL utama situs dan selector CSS (h4.media-heading a) yang digunakan untuk menemukan tautan provinsi dan kota/kabupaten.
#
# 3. List Penampung: Membuat list kosong hasil_data untuk menyimpan data yang berhasil di-scrape.
# * Mengambil Daftar Provinsi (Level 1):
# * Mengakses URL utama.
# * Menggunakan BeautifulSoup untuk mem-parsing halaman.
# * Mencari semua tautan provinsi menggunakan selector CSS yang ditentukan.
# * Jika tautan provinsi ditemukan, loop akan dimulai untuk setiap provinsi.
# 4. Memproses Provinsi dan Mengambil Kota/Kabupaten (Level 2):
# Untuk setiap tautan provinsi, kode mengambil nama provinsi dan URL lengkapnya.
# * Mengakses URL provinsi tersebut.
# * Mem-parsing halaman provinsi.
# * Mencari semua tautan kota/kabupaten di halaman provinsi menggunakan selector CSS yang sama.
# * Jika tautan kota/kabupaten ditemukan, loop akan berjalan untuk setiap kota/kabupaten.
# * Mengambil nama kota/kabupaten dan href tautannya.
# * Membangun tautan lengkap ke halaman detail kota/kabupaten.
# * Menambahkan data (Provinsi, Kota/Kabupaten, Link) ke list hasil_data.
# * Memberi jeda 1 detik setelah memproses setiap provinsi untuk menghindari pemblokiran.
# 5. Menyimpan Hasil ke CSV:
# * Setelah selesai memproses semua provinsi dan kota/kabupaten, kode membuat DataFrame Pandas dari list hasil_data.
# * Menyimpan DataFrame ke file CSV bernama DAFTAR_PROVINSI_KABUPATEN.csv.
# * Menampilkan 5 baris pertama dari DataFrame sebagai konfirmasi.

# %%
# Pastikan Anda sudah meng-install library ini:
# pip install requests beautifulsoup4 pandas lxml

import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

main_url = "https://www.indonesiapostcode.com/location/"
base_url = "https://www.indonesiapostcode.com"

# Selector CSS dari website indonesiapostcode
CSS_SELECTOR_LINK = "h4.media-heading a"

# List untuk menampung hasil akhir (Provinsi, Kabupaten, Link)
hasil_data = []

try:
    print("LEVEL 1: Mengambil daftar provinsi...")
    response_main = requests.get(main_url)
    soup_main = BeautifulSoup(response_main.text, 'html.parser')

    # 1. Gunakan .select() untuk menemukan semua link provinsi
    provinsi_links = soup_main.select(CSS_SELECTOR_LINK)

    if not provinsi_links:
        print("Tidak bisa menemukan link provinsi. Selector mungkin berubah.")
    else:
        for link_prov in provinsi_links:
            nama_provinsi = link_prov.text.strip()
            url_provinsi = base_url + link_prov['href']

            if 'location' not in url_provinsi: continue

            print(f"\nLEVEL 2: Memproses provinsi: {nama_provinsi}...")

            response_prov = requests.get(url_provinsi)
            soup_prov = BeautifulSoup(response_prov.text, 'html.parser')

            # 2. Gunakan selector YANG SAMA untuk menemukan link kota/kabupaten
            kabupaten_links = soup_prov.select(CSS_SELECTOR_LINK)

            if not kabupaten_links:
                print(f"  -> Tidak ada kabupaten ditemukan di {nama_provinsi}.")
            else:
                for link_kab in kabupaten_links:
                    nama_kabupaten = link_kab.text.strip()
                    href_kabupaten = link_kab['href'] # Ambil href untuk membangun link

                    if 'location' not in href_kabupaten: continue

                    # ======================================================
                    # PERUBAHAN: LANGSUNG SIMPAN, TIDAK MASUK KE LEVEL 3
                    # ======================================================
                    # Bangun link lengkap berdasarkan href kabupaten
                    link_lengkap = base_url + href_kabupaten

                    print(f"  -> Ditemukan: {nama_kabupaten}")
                    hasil_data.append({
                        'Provinsi': nama_provinsi,
                        'Kota_Kabupaten': nama_kabupaten,
                        'Link': link_lengkap # Tambahkan link ke data
                    })

            # Beri jeda 1 detik antar PROVINSI
            time.sleep(1)

    # 5. Simpan hasil akhir ke CSV
    if hasil_data:
        print("\n\nMenggabungkan semua data...")

        # Buat DataFrame langsung dari list 'hasil_data'
        df_final = pd.DataFrame(hasil_data)

        nama_file = "DAFTAR_PROVINSI_KABUPATEN.csv" # Ubah nama file CSV
        df_final.to_csv(nama_file, index=False)

        print(f"Selesai! Data disimpan di '{nama_file}'")
        print(df_final.head()) # Tampilkan 5 data pertama
    else:
        print("Tidak ada data yang berhasil diambil.")

except requests.RequestException as e:
    print(f"Terjadi error saat mengakses URL: {e}")
except Exception as e:
    print(f"Terjadi error: {e}")
# Out:
# LEVEL 1: Mengambil daftar provinsi...
#
# LEVEL 2: Memproses provinsi: Aceh (NAD)...
#   -> Ditemukan: Aceh Barat
#   -> Ditemukan: Aceh Barat Daya
#   -> Ditemukan: Aceh Besar
#   -> Ditemukan: Aceh Jaya
#   -> Ditemukan: Aceh Selatan
#   -> Ditemukan: Aceh Singkil
#   -> Ditemukan: Aceh Tamiang
#   -> Ditemukan: Aceh Tengah
#   -> Ditemukan: Aceh Tenggara
#   -> Ditemukan: Aceh Timur
#   -> Ditemukan: Aceh Utara
#   -> Ditemukan: Banda Aceh
#   -> Ditemukan: Bener Meriah
#   -> Ditemukan: Bireuen
#   -> Ditemukan: Gayo Lues
#   -> Ditemukan: Langsa
#   -> Ditemukan: Lhokseumawe
#   -> Ditemukan: Nagan Raya
#   -> Ditemukan: Pidie
#   -> Ditemukan: Pidie Jaya
#   -> Ditemukan: Sabang
#   -> Ditemukan: Simeulue
#   -> Ditemukan: Subulussalam
#
# LEVEL 2: Memproses provinsi: Bali...
#   -> Ditemukan: Badung
#   -> Ditemukan: Bangli
#   -> Ditemukan: Buleleng
#   -> Ditemukan: Denpasar
#   -> Ditemukan: Gianyar
#   -> Ditemukan: Jembrana
#   -> Ditemukan: Karangasem
#   -> Ditemukan: Klungkung
#   -> Ditemukan: Tabanan
#
# LEVEL 2: Memproses provinsi: Banten...
#   -> Ditemukan: Cilegon
#   -> Ditemukan: Lebak
#   -> Ditemukan: Pandeglang
#   -> Ditemukan: Serang
#   -> Ditemukan: Tangerang
#   -> Ditemukan: Tangerang Selatan
#
# LEVEL 2: Memproses provinsi: Bengkulu...
#   -> Ditemukan: Bengkulu
#   -> Ditemukan: Bengkulu Selatan
#   -> Ditemukan: Bengkulu Tengah
#   -> Ditemukan: Bengkulu Utara
#   -> Ditemukan: Kaur
#   -> Ditemukan: Kepahiang
#   -> Ditemukan: Lebong
#   -> Ditemukan: Muko Muko
#   -> Ditemukan: Rejang Lebong
#   -> Ditemukan: Seluma
#
# LEVEL 2: Memproses provinsi: DI Yogyakarta...
#   -> Ditemukan: Bantul
#   -> Ditemukan: Gunung Kidul
#   -> Ditemukan: Kulon Progo
#   -> Ditemukan: Sleman
#   -> Ditemukan: Yogyakarta
#
# LEVEL 2: Memproses provinsi: DKI Jakarta...
#   -> Ditemukan: Jakarta Barat
#   -> Ditemukan: Jakarta Pusat
#   -> Ditemukan: Jakarta Selatan
#   -> Ditemukan: Jakarta Timur
#   -> Ditemukan: Jakarta Utara
#   -> Ditemukan: Kepulauan Seribu
#
# LEVEL 2: Memproses provinsi: Gorontalo...
#   -> Ditemukan: Boalemo
#   -> Ditemukan: Bone Bolango
#   -> Ditemukan: Gorontalo
#   -> Ditemukan: Gorontalo Utara
#   -> Ditemukan: Pohuwato
#
# LEVEL 2: Memproses provinsi: Jambi...
#   -> Ditemukan: Batang Hari
#   -> Ditemukan: Bungo
#   -> Ditemukan: Jambi
#   -> Ditemukan: Kerinci
#   -> Ditemukan: Merangin
#   -> Ditemukan: Muaro Jambi
#   -> Ditemukan: Sarolangun
#   -> Ditemukan: Sungaipenuh
#   -> Ditemukan: Tanjung Jabung Barat
#   -> Ditemukan: Tanjung Jabung Timur
#   -> Ditemukan: Tebo
#
# LEVEL 2: Memproses provinsi: Jawa Barat...
#   -> Ditemukan: Bandung
#   -> Ditemukan: Bandung Barat
#   -> Ditemukan: Banjar
#   -> Ditemukan: Bekasi
#   -> Ditemukan: Bogor
#   -> Ditemukan: Ciamis
#   -> Ditemukan: Cianjur
#   -> Ditemukan: Cimahi
#   -> Ditemukan: Cirebon
#   -> Ditemukan: Depok
#   -> Ditemukan: Garut
#   -> Ditemukan: Indramayu
#   -> Ditemukan: Karawang
#   -> Ditemukan: Kuningan
#   -> Ditemukan: Majalengka
#   -> Ditemukan: Pangandaran
#   -> Ditemukan: Purwakarta
#   -> Ditemukan: Subang
#   -> Ditemukan: Sukabumi
#   -> Ditemukan: Sumedang
#   -> Ditemukan: Tasikmalaya
#
# LEVEL 2: Memproses provinsi: Jawa Tengah...
#   -> Ditemukan: Banjarnegara
#   -> Ditemukan: Banyumas
#   -> Ditemukan: Batang
#   -> Ditemukan: Blora
#   -> Ditemukan: Boyolali
#   -> Ditemukan: Brebes
#   -> Ditemukan: Cilacap
#   -> Ditemukan: Demak
#   -> Ditemukan: Grobogan
#   -> Ditemukan: Jepara
#   -> Ditemukan: Karanganyar
#   -> Ditemukan: Kebumen
#   -> Ditemukan: Kendal
#   -> Ditemukan: Klaten
#   -> Ditemukan: Kudus
#   -> Ditemukan: Magelang
#   -> Ditemukan: Pati
#   -> Ditemukan: Pekalongan
#   -> Ditemukan: Pemalang
#   -> Ditemukan: Purbalingga
#   -> Ditemukan: Purworejo
#   -> Ditemukan: Rembang
#   -> Ditemukan: Salatiga
#   -> Ditemukan: Semarang
#   -> Ditemukan: Sragen
#   -> Ditemukan: Sukoharjo
#   -> Ditemukan: Surakarta
#   -> Ditemukan: Tegal
#   -> Ditemukan: Temanggung
#   -> Ditemukan: Wonogiri
#   -> Ditemukan: Wonosobo
#
# LEVEL 2: Memproses provinsi: Jawa Timur...
#   -> Ditemukan: Bangkalan
#   -> Ditemukan: Banyuwangi
#   -> Ditemukan: Batu
#   -> Ditemukan: Blitar
#   -> Ditemukan: Bojonegoro
#   -> Ditemukan: Bondowoso
#   -> Ditemukan: Gresik
#   -> Ditemukan: Jember
#   -> Ditemukan: Jombang
#   -> Ditemukan: Kediri
#   -> Ditemukan: Lamongan
#   -> Ditemukan: Lumajang
#   -> Ditemukan: Madiun
#   -> Ditemukan: Magetan
#   -> Ditemukan: Malang
#   -> Ditemukan: Mojokerto
#   -> Ditemukan: Nganjuk
#   -> Ditemukan: Ngawi
#   -> Ditemukan: Pacitan
#   -> Ditemukan: Pamekasan
#   -> Ditemukan: Pasuruan
#   -> Ditemukan: Ponorogo
#   -> Ditemukan: Probolinggo
#   -> Ditemukan: Sampang
#   -> Ditemukan: Sidoarjo
#   -> Ditemukan: Situbondo
#   -> Ditemukan: Sumenep
#   -> Ditemukan: Surabaya
#   -> Ditemukan: Trenggalek
#   -> Ditemukan: Tuban
#   -> Ditemukan: Tulungagung
#
# LEVEL 2: Memproses provinsi: Kalimantan Barat...
#   -> Ditemukan: Bengkayang
#   -> Ditemukan: Kapuas Hulu
#   -> Ditemukan: Kayong Utara
#   -> Ditemukan: Ketapang
#   -> Ditemukan: Kubu Raya
#   -> Ditemukan: Landak
#   -> Ditemukan: Melawi
#   -> Ditemukan: Mempawah
#   -> Ditemukan: Pontianak
#   -> Ditemukan: Sambas
#   -> Ditemukan: Sanggau
#   -> Ditemukan: Sekadau
#   -> Ditemukan: Singkawang
#   -> Ditemukan: Sintang
#
# LEVEL 2: Memproses provinsi: Kalimantan Selatan...
#   -> Ditemukan: Balangan
#   -> Ditemukan: Banjar
#   -> Ditemukan: Banjarbaru
#   -> Ditemukan: Banjarmasin
#   -> Ditemukan: Barito Kuala
#   -> Ditemukan: Hulu Sungai Selatan
#   -> Ditemukan: Hulu Sungai Tengah
#   -> Ditemukan: Hulu Sungai Utara
#   -> Ditemukan: Kotabaru
#   -> Ditemukan: Tabalong
#   -> Ditemukan: Tanah Bumbu
#   -> Ditemukan: Tanah Laut
#   -> Ditemukan: Tapin
#
# LEVEL 2: Memproses provinsi: Kalimantan Tengah...
#   -> Ditemukan: Barito Selatan
#   -> Ditemukan: Barito Timur
#   -> Ditemukan: Barito Utara
#   -> Ditemukan: Gunung Mas
#   -> Ditemukan: Kapuas
#   -> Ditemukan: Katingan
#   -> Ditemukan: Kotawaringin Barat
#   -> Ditemukan: Kotawaringin Timur
#   -> Ditemukan: Lamandau
#   -> Ditemukan: Murung Raya
#   -> Ditemukan: Palangka Raya
#   -> Ditemukan: Pulang Pisau
#   -> Ditemukan: Seruyan
#   -> Ditemukan: Sukamara
#
# LEVEL 2: Memproses provinsi: Kalimantan Timur...
#   -> Ditemukan: Balikpapan
#   -> Ditemukan: Berau
#   -> Ditemukan: Bontang
#   -> Ditemukan: Kutai Barat
#   -> Ditemukan: Kutai Kartanegara
#   -> Ditemukan: Kutai Timur
#   -> Ditemukan: Mahakam Ulu
#   -> Ditemukan: Paser
#   -> Ditemukan: Penajam Paser Utara
#   -> Ditemukan: Samarinda
#
# LEVEL 2: Memproses provinsi: Kalimantan Utara...
#   -> Ditemukan: Bulungan
#   -> Ditemukan: Malinau
#   -> Ditemukan: Nunukan
#   -> Ditemukan: Tana Tidung
#   -> Ditemukan: Tarakan
#
# LEVEL 2: Memproses provinsi: Kepulauan Bangka Belitung...
#   -> Ditemukan: Bangka
#   -> Ditemukan: Bangka Barat
#   -> Ditemukan: Bangka Selatan
#   -> Ditemukan: Bangka Tengah
#   -> Ditemukan: Belitung
#   -> Ditemukan: Belitung Timur
#   -> Ditemukan: Pangkal Pinang
#
# LEVEL 2: Memproses provinsi: Kepulauan Riau...
#   -> Ditemukan: Batam
#   -> Ditemukan: Bintan
#   -> Ditemukan: Karimun
#   -> Ditemukan: Kepulauan Anambas
#   -> Ditemukan: Lingga
#   -> Ditemukan: Natuna
#   -> Ditemukan: Tanjung Pinang
#
# LEVEL 2: Memproses provinsi: Lampung...
#   -> Ditemukan: Bandar Lampung
#   -> Ditemukan: Lampung Barat
#   -> Ditemukan: Lampung Selatan
#   -> Ditemukan: Lampung Tengah
#   -> Ditemukan: Lampung Timur
#   -> Ditemukan: Lampung Utara
#   -> Ditemukan: Mesuji
#   -> Ditemukan: Metro
#   -> Ditemukan: Pesawaran
#   -> Ditemukan: Pesisir Barat
#   -> Ditemukan: Pringsewu
#   -> Ditemukan: Tanggamus
#   -> Ditemukan: Tulang Bawang
#   -> Ditemukan: Tulang Bawang Barat
#   -> Ditemukan: Way Kanan
#
# LEVEL 2: Memproses provinsi: Maluku...
#   -> Ditemukan: Ambon
#   -> Ditemukan: Buru
#   -> Ditemukan: Buru Selatan
#   -> Ditemukan: Kepulauan Aru
#   -> Ditemukan: Maluku Barat Daya
#   -> Ditemukan: Maluku Tengah
#   -> Ditemukan: Maluku Tenggara
#   -> Ditemukan: Maluku Tenggara Barat
#   -> Ditemukan: Seram Bagian Barat
#   -> Ditemukan: Seram Bagian Timur
#   -> Ditemukan: Tual
#
# LEVEL 2: Memproses provinsi: Maluku Utara...
#   -> Ditemukan: Halmahera Barat
#   -> Ditemukan: Halmahera Selatan
#   -> Ditemukan: Halmahera Tengah
#   -> Ditemukan: Halmahera Timur
#   -> Ditemukan: Halmahera Utara
#   -> Ditemukan: Kepulauan Sula
#   -> Ditemukan: Pulau Morotai
#   -> Ditemukan: Pulau Taliabu
#   -> Ditemukan: Ternate
#   -> Ditemukan: Tidore Kepulauan
#
# LEVEL 2: Memproses provinsi: Nusa Tenggara Barat (NTB)...
#   -> Ditemukan: Bima
#   -> Ditemukan: Dompu
#   -> Ditemukan: Lombok Barat
#   -> Ditemukan: Lombok Tengah
#   -> Ditemukan: Lombok Timur
#   -> Ditemukan: Lombok Utara
#   -> Ditemukan: Mataram
#   -> Ditemukan: Sumbawa
#   -> Ditemukan: Sumbawa Barat
#
# LEVEL 2: Memproses provinsi: Nusa Tenggara Timur (NTT)...
#   -> Ditemukan: Alor
#   -> Ditemukan: Belu
#   -> Ditemukan: Ende
#   -> Ditemukan: Flores Timur
#   -> Ditemukan: Kupang
#   -> Ditemukan: Lembata
#   -> Ditemukan: Malaka
#   -> Ditemukan: Manggarai
#   -> Ditemukan: Manggarai Barat
#   -> Ditemukan: Manggarai Timur
#   -> Ditemukan: Nagekeo
#   -> Ditemukan: Ngada
#   -> Ditemukan: Rote Ndao
#   -> Ditemukan: Sabu Raijua
#   -> Ditemukan: Sikka
#   -> Ditemukan: Sumba Barat
#   -> Ditemukan: Sumba Barat Daya
#   -> Ditemukan: Sumba Tengah
#   -> Ditemukan: Sumba Timur
#   -> Ditemukan: Timor Tengah Selatan
#   -> Ditemukan: Timor Tengah Utara
#
# LEVEL 2: Memproses provinsi: Papua...
#   -> Ditemukan: Asmat
#   -> Ditemukan: Biak Numfor
#   -> Ditemukan: Boven Digoel
#   -> Ditemukan: Deiyai
#   -> Ditemukan: Dogiyai
#   -> Ditemukan: Intan Jaya
#   -> Ditemukan: Jayapura
#   -> Ditemukan: Jayawijaya
#   -> Ditemukan: Keerom
#   -> Ditemukan: Kepulauan Yapen
#   -> Ditemukan: Lanny Jaya
#   -> Ditemukan: Mamberamo Raya
#   -> Ditemukan: Mamberamo Tengah
#   -> Ditemukan: Mappi
#   -> Ditemukan: Merauke
#   -> Ditemukan: Mimika
#   -> Ditemukan: Nabire
#   -> Ditemukan: Nduga
#   -> Ditemukan: Paniai
#   -> Ditemukan: Pegunungan Bintang
#   -> Ditemukan: Puncak
#   -> Ditemukan: Puncak Jaya
#   -> Ditemukan: Sarmi
#   -> Ditemukan: Supiori
#   -> Ditemukan: Tolikara
#   -> Ditemukan: Waropen
#   -> Ditemukan: Yahukimo
#   -> Ditemukan: Yalimo
#
# LEVEL 2: Memproses provinsi: Papua Barat...
#   -> Ditemukan: Fakfak
#   -> Ditemukan: Kaimana
#   -> Ditemukan: Manokwari
#   -> Ditemukan: Manokwari Selatan
#   -> Ditemukan: Maybrat
#   -> Ditemukan: Pegunungan Arfak
#   -> Ditemukan: Raja Ampat
#   -> Ditemukan: Sorong
#   -> Ditemukan: Sorong Selatan
#   -> Ditemukan: Tambrauw
#   -> Ditemukan: Teluk Bintuni
#   -> Ditemukan: Teluk Wondama
#
# LEVEL 2: Memproses provinsi: Riau...
#   -> Ditemukan: Bengkalis
#   -> Ditemukan: Dumai
#   -> Ditemukan: Indragiri Hilir
#   -> Ditemukan: Indragiri Hulu
#   -> Ditemukan: Kampar
#   -> Ditemukan: Kepulauan Meranti
#   -> Ditemukan: Kuantan Singingi
#   -> Ditemukan: Pekanbaru
#   -> Ditemukan: Pelalawan
#   -> Ditemukan: Rokan Hilir
#   -> Ditemukan: Rokan Hulu
#   -> Ditemukan: Siak
#
# LEVEL 2: Memproses provinsi: Sulawesi Barat...
#   -> Ditemukan: Majene
#   -> Ditemukan: Mamasa
#   -> Ditemukan: Mamuju
#   -> Ditemukan: Mamuju Tengah
#   -> Ditemukan: Mamuju Utara
#   -> Ditemukan: Polewali Mandar
#
# LEVEL 2: Memproses provinsi: Sulawesi Selatan...
#   -> Ditemukan: Bantaeng
#   -> Ditemukan: Barru
#   -> Ditemukan: Bone
#   -> Ditemukan: Bulukumba
#   -> Ditemukan: Enrekang
#   -> Ditemukan: Gowa
#   -> Ditemukan: Jeneponto
#   -> Ditemukan: Kepulauan Selayar
#   -> Ditemukan: Luwu
#   -> Ditemukan: Luwu Timur
#   -> Ditemukan: Luwu Utara
#   -> Ditemukan: Makassar
#   -> Ditemukan: Maros
#   -> Ditemukan: Palopo
#   -> Ditemukan: Pangkajene Kepulauan
#   -> Ditemukan: Parepare
#   -> Ditemukan: Pinrang
#   -> Ditemukan: Sidenreng Rappang
#   -> Ditemukan: Sinjai
#   -> Ditemukan: Soppeng
#   -> Ditemukan: Takalar
#   -> Ditemukan: Tana Toraja
#   -> Ditemukan: Toraja Utara
#   -> Ditemukan: Wajo
#
# LEVEL 2: Memproses provinsi: Sulawesi Tengah...
#   -> Ditemukan: Banggai
#   -> Ditemukan: Banggai Kepulauan
#   -> Ditemukan: Banggai Laut
#   -> Ditemukan: Buol
#   -> Ditemukan: Donggala
#   -> Ditemukan: Morowali
#   -> Ditemukan: Morowali Utara
#   -> Ditemukan: Palu
#   -> Ditemukan: Parigi Moutong
#   -> Ditemukan: Poso
#   -> Ditemukan: Sigi
#   -> Ditemukan: Tojo Una-Una
#   -> Ditemukan: Toli-Toli
#
# LEVEL 2: Memproses provinsi: Sulawesi Tenggara...
#   -> Ditemukan: Bau-Bau
#   -> Ditemukan: Bombana
#   -> Ditemukan: Buton
#   -> Ditemukan: Buton Selatan
#   -> Ditemukan: Buton Tengah
#   -> Ditemukan: Buton Utara
#   -> Ditemukan: Kendari
#   -> Ditemukan: Kolaka
#   -> Ditemukan: Kolaka Timur
#   -> Ditemukan: Kolaka Utara
#   -> Ditemukan: Konawe
#   -> Ditemukan: Konawe Kepulauan
#   -> Ditemukan: Konawe Selatan
#   -> Ditemukan: Konawe Utara
#   -> Ditemukan: Muna
#   -> Ditemukan: Muna Barat
#   -> Ditemukan: Wakatobi
#
# LEVEL 2: Memproses provinsi: Sulawesi Utara...
#   -> Ditemukan: Bitung
#   -> Ditemukan: Bolaang Mongondow
#   -> Ditemukan: Bolaang Mongondow Selatan
#   -> Ditemukan: Bolaang Mongondow Timur
#   -> Ditemukan: Bolaang Mongondow Utara
#   -> Ditemukan: Kepulauan Sangihe
#   -> Ditemukan: Kepulauan Talaud
#   -> Ditemukan: Kotamobagu
#   -> Ditemukan: Manado
#   -> Ditemukan: Minahasa
#   -> Ditemukan: Minahasa Selatan
#   -> Ditemukan: Minahasa Tenggara
#   -> Ditemukan: Minahasa Utara
#   -> Ditemukan: Tomohon
#
# LEVEL 2: Memproses provinsi: Sumatera Barat...
#   -> Ditemukan: Agam
#   -> Ditemukan: Bukittinggi
#   -> Ditemukan: Dharmasraya
#   -> Ditemukan: Kepulauan Mentawai
#   -> Ditemukan: Lima Puluh Kota
#   -> Ditemukan: Padang
#   -> Ditemukan: Padang Panjang
#   -> Ditemukan: Padang Pariaman
#   -> Ditemukan: Pariaman
#   -> Ditemukan: Pasaman
#   -> Ditemukan: Pasaman Barat
#   -> Ditemukan: Payakumbuh
#   -> Ditemukan: Pesisir Selatan
#   -> Ditemukan: Sawah Lunto
#   -> Ditemukan: Sijunjung
#   -> Ditemukan: Solok
#   -> Ditemukan: Solok Selatan
#   -> Ditemukan: Tanah Datar
#
# LEVEL 2: Memproses provinsi: Sumatera Selatan...
#   -> Ditemukan: Banyuasin
#   -> Ditemukan: Empat Lawang
#   -> Ditemukan: Lahat
#   -> Ditemukan: Lubuk Linggau
#   -> Ditemukan: Muara Enim
#   -> Ditemukan: Musi Banyuasin
#   -> Ditemukan: Musi Rawas
#   -> Ditemukan: Musi Rawas Utara
#   -> Ditemukan: Ogan Ilir
#   -> Ditemukan: Ogan Komering Ilir
#   -> Ditemukan: Ogan Komering Ulu
#   -> Ditemukan: Ogan Komering Ulu Selatan
#   -> Ditemukan: Ogan Komering Ulu Timur
#   -> Ditemukan: Pagar Alam
#   -> Ditemukan: Palembang
#   -> Ditemukan: Penukal Abab Lematang Ilir
#   -> Ditemukan: Prabumulih
#
# LEVEL 2: Memproses provinsi: Sumatera Utara...
#   -> Ditemukan: Asahan
#   -> Ditemukan: Batu Bara
#   -> Ditemukan: Binjai
#   -> Ditemukan: Dairi
#   -> Ditemukan: Deli Serdang
#   -> Ditemukan: Gunungsitoli
#   -> Ditemukan: Humbang Hasundutan
#   -> Ditemukan: Karo
#   -> Ditemukan: Labuhanbatu
#   -> Ditemukan: Labuhanbatu Selatan
#   -> Ditemukan: Labuhanbatu Utara
#   -> Ditemukan: Langkat
#   -> Ditemukan: Mandailing Natal
#   -> Ditemukan: Medan
#   -> Ditemukan: Nias
#   -> Ditemukan: Nias Barat
#   -> Ditemukan: Nias Selatan
#   -> Ditemukan: Nias Utara
#   -> Ditemukan: Padang Lawas
#   -> Ditemukan: Padang Lawas Utara
#   -> Ditemukan: Padang Sidempuan
#   -> Ditemukan: Pakpak Bharat
#   -> Ditemukan: Pematang Siantar
#   -> Ditemukan: Samosir
#   -> Ditemukan: Serdang Bedagai
#   -> Ditemukan: Sibolga
#   -> Ditemukan: Simalungun
#   -> Ditemukan: Tanjung Balai
#   -> Ditemukan: Tapanuli Selatan
#   -> Ditemukan: Tapanuli Tengah
#   -> Ditemukan: Tapanuli Utara
#   -> Ditemukan: Tebing Tinggi
#   -> Ditemukan: Toba Samosir
#
#
# Menggabungkan semua data...
# Selesai! Data disimpan di 'DAFTAR_PROVINSI_KABUPATEN.csv'
#      Provinsi   Kota_Kabupaten  \
# 0  Aceh (NAD)       Aceh Barat
# 1  Aceh (NAD)  Aceh Barat Daya
# 2  Aceh (NAD)       Aceh Besar
# 3  Aceh (NAD)        Aceh Jaya
# 4  Aceh (NAD)     Aceh Selatan
#
#                                                 Link
# 0  https://www.indonesiapostcode.com/location/ace...
# 1  https://www.indonesiapostcode.com/location/ace...
# 2  https://www.indonesiapostcode.com/location/ace...
# 3  https://www.indonesiapostcode.com/location/ace...
# 4  https://www.indonesiapostcode.com/location/ace...

# %%
display(df_final.head(100))
# Out:
#        Provinsi   Kota_Kabupaten  \
# 0    Aceh (NAD)       Aceh Barat
# 1    Aceh (NAD)  Aceh Barat Daya
# 2    Aceh (NAD)       Aceh Besar
# 3    Aceh (NAD)        Aceh Jaya
# 4    Aceh (NAD)     Aceh Selatan
# ..          ...              ...
# 95   Jawa Barat      Tasikmalaya
# 96  Jawa Tengah     Banjarnegara
# 97  Jawa Tengah         Banyumas
# 98  Jawa Tengah           Batang
# 99  Jawa Tengah            Blora
#
#                                                  Link
# 0   https://www.indonesiapostcode.com/location/ace...
# 1   https://www.indonesiapostcode.com/location/ace...
# 2   https://www.indonesiapostcode.com/location/ace...
# 3   https://www.indonesiapostcode.com/location/ace...
# 4   https://www.indonesiapostcode.com/location/ace...
# ..                                                ...
# 95  https://www.indonesiapostcode.com/location/jaw...
# 96  https://www.indonesiapostcode.com/location/jaw...
# 97  https://www.indonesiapostcode.com/location/jaw...
# 98  https://www.indonesiapostcode.com/location/jaw...
# 99  https://www.indonesiapostcode.com/location/jaw...
#
# [100 rows x 3 columns]

# %%
# Hitung jumlah provinsi unik
jumlah_provinsi = df_final['Provinsi'].nunique()
print(f"Jumlah provinsi di Indonesia adalah: {jumlah_provinsi}")

# Hitung jumlah kota/kabupaten (jumlah baris dalam DataFrame)
jumlah_kota_kabupaten = len(df_final)
print(f"Jumlah kota/kabupaten di Indonesia adalah: {jumlah_kota_kabupaten}")
# Out:
# Jumlah provinsi di Indonesia adalah: 34
# Jumlah kota/kabupaten di Indonesia adalah: 488

# %%
# Hitung jumlah kota/kabupaten per provinsi
jumlah_per_provinsi = df_final.groupby('Provinsi').size().reset_index(name='Jumlah_Kota_Kabupaten')

display(jumlah_per_provinsi)
# Out:
#                      Provinsi  Jumlah_Kota_Kabupaten
# 0                  Aceh (NAD)                     23
# 1                        Bali                      9
# 2                      Banten                      6
# 3                    Bengkulu                     10
# 4               DI Yogyakarta                      5
# 5                 DKI Jakarta                      6
# 6                   Gorontalo                      5
# 7                       Jambi                     11
# 8                  Jawa Barat                     21
# 9                 Jawa Tengah                     31
# 10                 Jawa Timur                     31
# 11           Kalimantan Barat                     14
# 12         Kalimantan Selatan                     13
# 13          Kalimantan Tengah                     14
# 14           Kalimantan Timur                     10
# 15           Kalimantan Utara                      5
# 16  Kepulauan Bangka Belitung                      7
# 17             Kepulauan Riau                      7
# 18                    Lampung                     15
# 19                     Maluku                     11
# 20               Maluku Utara                     10
# 21  Nusa Tenggara Barat (NTB)                      9
# 22  Nusa Tenggara Timur (NTT)                     21
# 23                      Papua                     28
# 24                Papua Barat                     12
# 25                       Riau                     12
# 26             Sulawesi Barat                      6
# 27           Sulawesi Selatan                     24
# 28            Sulawesi Tengah                     13
# 29          Sulawesi Tenggara                     17
# 30             Sulawesi Utara                     14
# 31             Sumatera Barat                     18
# 32           Sumatera Selatan                     17
# 33             Sumatera Utara                     33
